# %%
import requests
import os
import argparse
import yaml
import re
import subprocess
import json
import urllib

# %%
"""
This function is useful in parsing the yaml file for an entire canvas course resulting in the extraction of a dictionary with the module id numbers as the keys and the lesson detail as the values.
"""
def lessons_list(yaml_file):
    with open(yaml_file) as f:
        data = yaml.load(f, Loader=yaml.FullLoader)
    lesson_data = {}

    for i in data[':modules']:
        lesson_data[i[':id']] = []
        for j in i[':lessons']:
            if j['type'] == 'Assignment' or j['type'] == 'Page':
                lesson_data[i[':id']].append(j['url'])
            else:
                continue
            
    return lesson_data

# %%
def equation(result):
    """
    Takes in the result of a regex match and returns the canvas string for rendering latex
    """
    string = result.group()
    item = string.split('?math=')[1].strip('" />')
    item_encoded = "https://learning.flatironschool.com/equation_images/"+urllib.parse.quote(item)
    return f"""<img class="equation_image" title="{item}" src="{item_encoded}" alt="{"LaTeX: "+item}" data-equation-content="{item}" />"""

# %%
def fix_canvas_latex(page_string):
    with open('test_file.txt', "r")as f:
        data = f.read()re.sub('<img src="https://render.githubusercontent.com/render/math\?math=.*?" />', equation, data)
    file = 
    with open('fixed_file.txt', 'w')as j:
        j.write(file)

# %%
"""
This function takes in a string and fixes the latex rendering for canvas 
Returns the fixed string as a string
"""
def fix_canvas(page_file):
    with open(page_file)as j:
        page_string = j.read()
    print(page_string[:100])
    contents = re.sub('<img src="https://render.githubusercontent.com/render/math\?math=.*?" />', equation, page_string)
    contents = re.sub('<img src="https://render.githubusercontent.com/render/math\?math=.*?"/>', equation, contents)
    contents = re.sub('<img src="https://render.githubusercontent.com/render/math\?math=.*?">', equation, contents)
    with open('fixed_file.txt', 'w')as f:
        f.write(contents)

# %%
"""
Takes a canvas lesson url and returns the lesson contents as a dictionary with the following keys:
name: the name of the lesson as it appears in the canvas page header

description: this is the html content of the lesson if it is a 'page'
body: this is the html content of the lesson if it is an 'assignment'

type: this is the type of lesson either a page or assignment

The function retrieves the lesson html content from canvas and returns that content as a string
"""
def canvas_details(canvas_url):    
    lesson_url = canvas_url.strip()
    command = ('github-to-canvas',  '--read-from-canvas', lesson_url)
    process = subprocess.Popen(command, stdout=subprocess.PIPE)
    raw_data = process.communicate()[0]
    data = yaml.safe_load(raw_data)
    lesson_type = data['type']
    if lesson_type == 'Page':
        if (len(re.findall('<img src="https://render.githubusercontent.com/render/math\?math=', data['body']))) == 0:
            print('Not a LaTeX Repo')
            lesson_type = 'Not LaTeX'
            file = None
            name = None
        else:
            file = data['body']
            name = data['title']
    elif lesson_type == 'Assignment':
        if (len(re.findall('<img src="https://render.githubusercontent.com/render/math\?math=', data['description']))) == 0:
            print('Not a LaTeX Repo')
            lesson_type = 'Not LaTeX'
            file = None
            name = None
        else:
            file = data['description']
            name = data['name']
    return lesson_url, file, lesson_type, name

# %%
"""
This takes the canvas_url, page_html, and lesson type and replaces the html in canvas with the new file 'page_html'
return is the response json object
"""
def update_details(canvas_url, file, lesson_type):
    with open(file, 'r')as f:
        page_html = f.read()
    if lesson_type == 'Not LaTeX':
        print("Not a LaTeX lesson")
    if lesson_type == 'Page':
        url = canvas_url
        payload = {'wiki_page[body]': page_html}
        head = {'Authorization': f"Bearer {os.environ.get('CANVAS_API_KEY')}"}
        response = requests.put(url=url, headers=head, data=payload)
        return response.json()

    if lesson_type == 'Assignment':
        url = canvas_url
        payload = {'assignment[description]': page_html}
        head = {'Authorization': f"Bearer {os.environ.get('CANVAS_API_KEY')}"}
        response = requests.put(url=url, headers=head, data=payload)
        return response.json()

# %%
def fix_course_latex(yaml_file):
    lessons = lessons_list(yaml_file=yaml_file)
    for j in lessons:
        for i in lessons[j]:
            lesson_url, data_temp, page_type, name = canvas_details(i)
            if page_type == 'Not LaTeX':
                print(f'{name} does not have any LaTeX formulas in it\nMoving on to the next item')
            else:
                with open('temp_file.txt', 'w')as j:
                    j.write(data_temp)
                print(f'Fixing {name}')
                fix_canvas('temp_file.txt')
                print(f'Updating {name} at \n {lesson_url}')
                update_details(canvas_url=lesson_url, file='fixed_file.txt', lesson_type=page_type)
                print(f'Sucess!! Done with {name}, moving on to the next one.')

# %%
fix_course_latex('full_course_download.yml')
# Out:
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Measures of Dispersion
# <h1>Measures of Dispersion</h1>  <h2>Introduction</h2>  <p>Previously, you learned about three measu
# Updating Measures of Dispersion at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131393
# Sucess!! Done with Measures of Dispersion, moving on to the next one.
# Fixing Covariance and Correlation
# <h1>Covariance and Correlation</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn how the
# Updating Covariance and Correlation at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131362
# Sucess!! Done with Covariance and Correlation, moving on to the next one.
# Fixing Data Visualization
# <h1>Data Visualization</h1>  <h2>Introduction</h2>  <p>This lesson introduces data visualization usi
# Updating Data Visualization at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131370
# Sucess!! Done with Data Visualization, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Collaborating with Git Branches
# <h1>Collaborating with Git Branches</h1>  <h2>Introduction</h2>  <p>So far we've primarily presented
# Updating Collaborating with Git Branches at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/collaborating-with-git-branches
# Sucess!! Done with Collaborating with Git Branches, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing File Input and Output in Python
# <h1>File Input and Output in Python</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn abo
# Updating File Input and Output in Python at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131455
# Sucess!! Done with File Input and Output in Python, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Accessing Data within Pandas
# <h1>Accessing Data within Pandas</h1>  <h2>Introduction</h2>  <p>In this lesson, we're going to dig
# Updating Accessing Data within Pandas at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131411
# Sucess!! Done with Accessing Data within Pandas, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing MongoDB
# <h1>MongoDB</h1>  <h2>Introduction</h2>  <p>In this lesson, we'll learn about the popular NoSQL data
# Updating MongoDB at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131499
# Sucess!! Done with MongoDB, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Using the Yelp API - Codealong
# <h1>Using the Yelp API - Codealong</h1>  <h2>Introduction</h2>  <p>Now that we've discussed HTTP req
# Updating Using the Yelp API - Codealong at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131557
# Sucess!! Done with Using the Yelp API - Codealong, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Introduction to Sets
# <h1>Introduction to Sets</h1>
# <h2>Introduction</h2>
# <p>You have definitely heard of sets before. In
# Updating Introduction to Sets at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/introduction-to-sets
# Sucess!! Done with Introduction to Sets, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Permutations and Factorials
# <h1>Permutations and Factorials</h1>  <h2>Introduction</h2>  <p>In the previous lab, you defined a f
# Updating Permutations and Factorials at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/permutations-and-factorials
# Sucess!! Done with Permutations and Factorials, moving on to the next one.
# Fixing Combinations
# <h1>Combinations</h1>
# <h2>Introduction</h2>
# <p>In the previous section, you learned about how to app
# Updating Combinations at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/combinations
# Sucess!! Done with Combinations, moving on to the next one.
# Fixing Conditional Probability
# <h1>Conditional Probability</h1>
# <h2>Introduction</h2>
# <p>In the previous lessons and labs, you lear
# Updating Conditional Probability at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/conditional-probability
# Sucess!! Done with Conditional Probability, moving on to the next one.
# Fixing Partitioning and the Law of Total Probability
# <h1>Partitioning and the Law of Total Probability</h1>  <h2>Introduction</h2>  <p>In this lesson, we
# Updating Partitioning and the Law of Total Probability at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/partitioning-and-the-law-of-total-probability
# Sucess!! Done with Partitioning and the Law of Total Probability, moving on to the next one.
# Fixing Combinatorics and Probability - Recap
# <h1>Combinatorics and Probability - Recap</h1>  <h2>Introduction</h2>  <p>In this section, you learn
# Updating Combinatorics and Probability - Recap at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/combinatorics-and-probability-recap
# Sucess!! Done with Combinatorics and Probability - Recap, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Statistical Distributions and Their Use Cases
# <h1>Statistical Distributions and Their Use Cases</h1>
# <h2>Introduction</h2>
# <p>As a data scientist,
# Updating Statistical Distributions and Their Use Cases at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/statistical-distributions-and-their-use-cases
# Sucess!! Done with Statistical Distributions and Their Use Cases, moving on to the next one.
# Fixing The Probability Mass Function
# <h1>The Probability Mass Function (PMF)</h1>
# <h2>Introduction</h2>
# <p>In this lesson, you'll look at
# Updating The Probability Mass Function at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131669
# Sucess!! Done with The Probability Mass Function, moving on to the next one.
# Fixing The Probability Density Function
# <h1>The Probability Density Function (PDF)</h1>
# <h2>Introduction</h2>
# <p>So far, you learned about d
# Updating The Probability Density Function at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131667
# Sucess!! Done with The Probability Density Function, moving on to the next one.
# Fixing The Cumulative Distribution Function
# <h1>The Cumulative Distribution Function</h1>
# <h2>Introduction</h2>
# <p>The PMF function that we saw
# Updating The Cumulative Distribution Function at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/the-cumulative-distribution-function
# Sucess!! Done with The Cumulative Distribution Function, moving on to the next one.
# Fixing The Bernoulli and Binomial Distribution
# <h1>Bernoulli and Binomial Distribution</h1>
# <h2>Introduction</h2>
# <p>Now that you learned about pro
# Updating The Bernoulli and Binomial Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131657
# Sucess!! Done with The Bernoulli and Binomial Distribution, moving on to the next one.
# Fixing The Normal Distribution
# <h1>The Normal Distribution</h1>
# <h2>Introduction</h2>
# <p>For data scientists and machine learning p
# Updating The Normal Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131664
# Sucess!! Done with The Normal Distribution, moving on to the next one.
# Fixing The Standard Normal Distribution
# <h1>The Standard Normal Distribution</h1>
# <h2>Introduction</h2>
# <p>In this lesson, we will introduce
# Updating The Standard Normal Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131671
# Sucess!! Done with The Standard Normal Distribution, moving on to the next one.
# Fixing Skewness and Kurtosis
# <h1>Skewness and Kurtosis</h1>
# <h2>Introduction</h2>
# <p>We have previously identified a normal distr
# Updating Skewness and Kurtosis at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/skewness-and-kurtosis
# Sucess!! Done with Skewness and Kurtosis, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Confidence Intervals with T-Distribution
# <h1>Confidence Intervals with T-Distribution
# </h1>
# <h2>Introduction</h2>
# <p>We've started to take a
# Updating Confidence Intervals with T-Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131591
# Sucess!! Done with Confidence Intervals with T-Distribution, moving on to the next one.
# Fixing Introduction to Statistical Significance
# <h1>Introduction to Statistical Significance</h1>
# <h2>Introduction</h2>
# <p>Now that you have learned
# Updating Introduction to Statistical Significance at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131609
# Sucess!! Done with Introduction to Statistical Significance, moving on to the next one.
# Fixing Central Limit Theorem and Confidence Intervals - Recap
# <h1>Central Limit Theorem and Confidence Intervals - Recap</h1>  <h2>Introduction</h2>  <p>This shor
# Updating Central Limit Theorem and Confidence Intervals - Recap at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/central-limit-theorem-and-confidence-intervals-recap
# Sucess!! Done with Central Limit Theorem and Confidence Intervals - Recap, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Introduction to Experimental Design
# <h1>Introduction to Experimental Design</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn
# Updating Introduction to Experimental Design at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/introduction-to-experimental-design
# Sucess!! Done with Introduction to Experimental Design, moving on to the next one.
# Fixing Statistical Testing with z-score and p-value
# <h1>Statistical Testing with z-score and p-value</h1>  <h2>Introduction</h2>  <p>In this lesson, you
# Updating Statistical Testing with z-score and p-value at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131656
# Sucess!! Done with Statistical Testing with z-score and p-value, moving on to the next one.
# Fixing P-Values and the Null Hypothesis
# <h1>P-Values and the Null Hypothesis</h1>
# <h2>Introduction</h2>
# <p>In this lesson, you'll dig deeper
# Updating P-Values and the Null Hypothesis at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/p-values-and-the-null-hypothesis
# Sucess!! Done with P-Values and the Null Hypothesis, moving on to the next one.
# Fixing One-Sample z-test
# <h1>One-Sample z-Test</h1>
# <h2>Introduction</h2>
# <p>A one-sample <img src="https://render.githubuser
# Updating One-Sample z-test at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131625
# Sucess!! Done with One-Sample z-test, moving on to the next one.
# Fixing Effect Sizes
# <h1>Effect Size</h1>  <h2>Introduction</h2>  <p>When comparing results between groups, and results p
# Updating Effect Sizes at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131595
# Sucess!! Done with Effect Sizes, moving on to the next one.
# Fixing Conducting T-Tests
# <h1>Conducting T-Tests</h1>
# <h2>Introduction</h2>
# <p>Previously you learned how to construct confide
# Updating Conducting T-Tests at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131589
# Sucess!! Done with Conducting T-Tests, moving on to the next one.
# Fixing Type 1 and Type 2 Errors
# <h1>Type I and Type II errors</h1>
# <h2>Introduction</h2>
# <p>In hypothesis testing, you are performin
# Updating Type 1 and Type 2 Errors at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131675
# Sucess!! Done with Type 1 and Type 2 Errors, moving on to the next one.
# Fixing Resampling Methods
# <h1>Resampling Methods</h1>  <h2>Introduction</h2>  <p>Resampling techniques are modern statistical
# Updating Resampling Methods at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/resampling-methods
# Sucess!! Done with Resampling Methods, moving on to the next one.
# Fixing Hypothesis Testing - Recap
# <h1>Hypothesis Testing - Recap</h1>
# <h2>Introduction</h2>
# <p>You just learned how to create an exper
# Updating Hypothesis Testing - Recap at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/hypothesis-testing-recap
# Sucess!! Done with Hypothesis Testing - Recap, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Statistical Power and ANOVA -  Introduction
# <h1>Statistical Power and ANOVA -  Introduction</h1>  <h2>Introduction</h2>  <p>In this section you'
# Updating Statistical Power and ANOVA -  Introduction at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/statistical-power-and-anova-introduction
# Sucess!! Done with Statistical Power and ANOVA -  Introduction, moving on to the next one.
# Fixing Statistical Power
# <h1>Statistical Power</h1>
# <h2>Introduction</h2>
# <p>You've started to investigate hypothesis testing
# Updating Statistical Power at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131654
# Sucess!! Done with Statistical Power, moving on to the next one.
# Fixing Welch's T-Test
# <h1>Welch's T-Test</h1>
# <h2>Introduction</h2>
# <p>Thus far, you've seen the traditional Student's t-t
# Updating Welch's T-Test at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/welchs-t-test
# Sucess!! Done with Welch's T-Test, moving on to the next one.
# Fixing The Multiple Comparisons Problem
# <h1>The Multiple Comparisons Problem</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn ab
# Updating The Multiple Comparisons Problem at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/the-multiple-comparisons-problem
# Sucess!! Done with The Multiple Comparisons Problem, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing The Kolmogorov-Smirnov Test
# <h1>The Kolmogorov-Smirnov Test</h1>
# <h2>Introduction</h2>
# <p>During data analysis, you have to sati
# Updating The Kolmogorov-Smirnov Test at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/the-kolmogorov-smirnov-test
# Sucess!! Done with The Kolmogorov-Smirnov Test, moving on to the next one.
# Fixing ANOVA
# <h1>ANOVA</h1>  <h2>Introduction</h2>  <p>ANOVA (Analysis of Variance) is a method for generalizing
# Updating ANOVA at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131578
# Sucess!! Done with ANOVA, moving on to the next one.
# Fixing Statistical Power and ANOVA - Recap
# <h1>Statistical Power and ANOVA - Recap</h1>  <h2>Introduction</h2>  <p>You've covered quite a bit i
# Updating Statistical Power and ANOVA - Recap at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/statistical-power-and-anova-recap
# Sucess!! Done with Statistical Power and ANOVA - Recap, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing AB Testing - Introduction
# <h1>AB Testing - Introduction</h1>  <h2>Introduction</h2>  <p>In this section, you'll get to develop
# Updating AB Testing - Introduction at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/ab-testing-introduction
# Sucess!! Done with AB Testing - Introduction, moving on to the next one.
# Fixing A/B Testing
# <h1>A/B Testing</h1>  <h2>Introduction</h2>  <p>You've now seen all of the statistical techniques an
# Updating A/B Testing at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/a-slash-b-testing
# Sucess!! Done with A/B Testing, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Bayesian Statistics - Introduction
# <h1>Bayesian Statistics - Introduction</h1>  <h2>Introduction</h2>  <p>In this section, you'll inves
# Updating Bayesian Statistics - Introduction at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/bayesian-statistics-introduction
# Sucess!! Done with Bayesian Statistics - Introduction, moving on to the next one.
# Fixing Bayesians vs Frequentists
# <h1>Bayesians vs Frequentists</h1>  <h2>Introduction</h2>  <p>Up until now, all of the statistical t
# Updating Bayesians vs Frequentists at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/bayesians-vs-frequentists
# Sucess!! Done with Bayesians vs Frequentists, moving on to the next one.
# Fixing Bayes' Theorem
# <h1>Bayes' Theorem</h1>
# <h2>Introduction</h2>
# <p>Bayes theorem is an indispensable law of probabilit
# Updating Bayes' Theorem at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/bayes-theorem
# Sucess!! Done with Bayes' Theorem, moving on to the next one.
# Fixing Maximum Likelihood Estimation (MLE)
# <h1>Maximum Likelihood Estimation (MLE)</h1>
# <h2>Introduction</h2>
# <p>"Parameter Inference" is one o
# Updating Maximum Likelihood Estimation (MLE) at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131612
# Sucess!! Done with Maximum Likelihood Estimation (MLE), moving on to the next one.
# Fixing Maximum A Posteriori Estimation (MAP) and Multinomial Bayes
# <h1>Maximum A Posteriori Estimation (MAP) and Multinomial Bayes</h1>  <h2>Introduction</h2>  <p>Maxi
# Updating Maximum A Posteriori Estimation (MAP) and Multinomial Bayes at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/maximum-a-posteriori-estimation-map-and-multinomial-bayes
# Sucess!! Done with Maximum A Posteriori Estimation (MAP) and Multinomial Bayes, moving on to the next one.
# Fixing Bayesian Statistics - Recap
# <h1>Bayesian Statistics - Recap</h1>  <h2>Introduction</h2>  <p>Well done! You covered a lot of grou
# Updating Bayesian Statistics - Recap at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/bayesian-statistics-recap
# Sucess!! Done with Bayesian Statistics - Recap, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Statistical Learning Theory
# <h1>Statistical Learning Theory</h1>
# <h2>Introduction</h2>
# <p>In this lesson, you'll be introduced t
# Updating Statistical Learning Theory at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/statistical-learning-theory
# Sucess!! Done with Statistical Learning Theory, moving on to the next one.
# Fixing Simple Linear Regression
# <h1>Simple Linear Regression</h1>
# <h2>Introduction</h2>
# <p>Regression analysis is often the first re
# Updating Simple Linear Regression at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/simple-linear-regression
# Sucess!! Done with Simple Linear Regression, moving on to the next one.
# Fixing Coefficient of Determination
# <h1>Coefficient of Determination</h1>  <h2>Introduction</h2>  <p>For linear regression analysis, as
# Updating Coefficient of Determination at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/coefficient-of-determination
# Sucess!! Done with Coefficient of Determination, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Ordinary Least Squares in Statsmodels (OLS)
# <h1>Ordinary Least Squared (OLS) in Statsmodels</h1>  <h2>Introduction</h2>  <p>So far, you learned
# Updating Ordinary Least Squares in Statsmodels (OLS) at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131627
# Sucess!! Done with Ordinary Least Squares in Statsmodels (OLS), moving on to the next one.
# Fixing Regression Diagnostics in Statsmodels
# <h1>Regression Diagnostics in Statsmodels</h1>
# <h2>Introduction</h2>
# <p>So far, you have looked main
# Updating Regression Diagnostics in Statsmodels at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131640
# Sucess!! Done with Regression Diagnostics in Statsmodels, moving on to the next one.
# Fixing Interpreting Significance and P-value
# <h1>Interpreting Significance and P-values</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll le
# Updating Interpreting Significance and P-value at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131603
# Sucess!! Done with Interpreting Significance and P-value, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Multiple Linear Regression
# <h1>Multiple Linear Regression</h1>
# <h2>Introduction</h2>
# <p>In this lecture, you'll be introduced t
# Updating Multiple Linear Regression at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131619
# Sucess!! Done with Multiple Linear Regression, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Log Transformations
# <h2>Log Transformations</h2>
# <h2>Introduction</h2>
# <p>In this lesson, you will take a look at logari
# Updating Log Transformations at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131611
# Sucess!! Done with Log Transformations, moving on to the next one.
# Fixing Feature Scaling and Normalization
# <h1>Feature Scaling and Normalization</h1>
# <h2>Introduction</h2>
# <p>Previously, you learned about ca
# Updating Feature Scaling and Normalization at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131598
# Sucess!! Done with Feature Scaling and Normalization, moving on to the next one.
# Fixing Multiple Linear Regression in Statsmodels
# <h1>Multiple Linear Regression in Statsmodels</h1>
# <h2>Introduction</h2>
# <p>In this lecture, you'll
# Updating Multiple Linear Regression in Statsmodels at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131620
# Sucess!! Done with Multiple Linear Regression in Statsmodels, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Model Fit in Linear Regression
# <h1>Model Fit in Linear Regression</h1>
# <h2>Introduction</h2>
# <p>In this lesson, you'll learn how to
# Updating Model Fit in Linear Regression at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131613
# Sucess!! Done with Model Fit in Linear Regression, moving on to the next one.
# Fixing Regression Model Validation
# <h1>Regression Model Validation</h1>
# <h2>Introduction</h2>
# <p>Previously you've briefly touched upon
# Updating Regression Model Validation at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131642
# Sucess!! Done with Regression Model Validation, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Extension to Linear Models - Introduction
# <h1>Extension to Linear Models - Introduction</h1>  <h2>Introduction</h2>  <p>In this section, you'l
# Updating Extension to Linear Models - Introduction at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/extension-to-linear-models-introduction
# Sucess!! Done with Extension to Linear Models - Introduction, moving on to the next one.
# Fixing Interactions
# <h1>Interactions</h1>
# <h2>Introduction</h2>
# <p>In this section, you'll learn about interactions and
# Updating Interactions at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131601
# Sucess!! Done with Interactions, moving on to the next one.
# Fixing Polynomial Regression
# <h1>Polynomial Regression</h1>  <h2>Introduction</h2>  <p>In the last lesson, you saw how you can ac
# Updating Polynomial Regression at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131636
# Sucess!! Done with Polynomial Regression, moving on to the next one.
# Fixing Bias-Variance Trade-Off
# <h1>Bias-Variance Tradeoff</h1>
# <h2>Introduction</h2>
# <p>You've seen how you can extend your linear
# Updating Bias-Variance Trade-Off at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131581
# Sucess!! Done with Bias-Variance Trade-Off, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing The Uniform Distribution
# <h1>The Uniform Distribution</h1>
# <h2>Introduction</h2>
# <p>Now that you've been introduced to both d
# Updating The Uniform Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/the-uniform-distribution
# Sucess!! Done with The Uniform Distribution, moving on to the next one.
# Fixing Poisson Distribution
# <h1>Poisson Distribution</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn about the <str
# Updating Poisson Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/poisson-distribution
# Sucess!! Done with Poisson Distribution, moving on to the next one.
# Fixing The Exponential Distribution
# <h1>Exponential Distributions</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn about the
# Updating The Exponential Distribution at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131660
# Sucess!! Done with The Exponential Distribution, moving on to the next one.
# Fixing (Re)sampling: Monte Carlo Simulations
# <h1>Monte Carlo Simulations</h1>  <h2>Introduction</h2>  <p>Monte Carlo simulations are useful appro
# Updating (Re)sampling: Monte Carlo Simulations at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131645
# Sucess!! Done with (Re)sampling: Monte Carlo Simulations, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Scrubbing and Cleaning Data
# <h1>Scrubbing and Cleaning Data</h1>
# <h2>Introduction</h2>
# <p>In this lesson, you'll review common i
# Updating Scrubbing and Cleaning Data at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/scrubbing-and-cleaning-data
# Sucess!! Done with Scrubbing and Cleaning Data, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Modeling Your Data
# <h1>Modeling Your Data</h1>
# <h2>Introduction</h2>
# <p>In this lesson you'll review the modeling proce
# Updating Modeling Your Data at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131615
# Sucess!! Done with Modeling Your Data, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Systems of Linear Equations
# <h1>Systems of Linear Equations</h1>  <h2>Introduction</h2>  <p>Linear algebra is a sub-field of mat
# Updating Systems of Linear Equations at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/systems-of-linear-equations
# Sucess!! Done with Systems of Linear Equations, moving on to the next one.
# Fixing Scalars, Vectors, Matrices, and Tensors - Code Along
# <h1>Scalars, Vectors, Matrices, and Tensors - Code Along</h1>
# <h2>Introduction</h2>
# <p>In this lesso
# Updating Scalars, Vectors, Matrices, and Tensors - Code Along at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131768
# Sucess!! Done with Scalars, Vectors, Matrices, and Tensors - Code Along, moving on to the next one.
# Fixing Matrix Multiplication - Code Along
# <h1>Matrix Multiplication - Code Along</h1>
# <h2>Introduction</h2>
# <p>Understanding matrix operations
# Updating Matrix Multiplication - Code Along at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131739
# Sucess!! Done with Matrix Multiplication - Code Along, moving on to the next one.
# Fixing Solving Systems of Linear Equations with NumPy - Code Along
# <h1>Solving Systems of Linear Equations with NumPy - Code Along</h1>
# <h2>Introduction</h2>
# <p>In thi
# Updating Solving Systems of Linear Equations with NumPy - Code Along at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131769
# Sucess!! Done with Solving Systems of Linear Equations with NumPy - Code Along, moving on to the next one.
# Fixing Regression Analysis using Linear Algebra and NumPy - Code Along
# <h1>Regression Analysis using Linear Algebra and NumPy - Code Along</h1>
# <h2>Introduction</h2>
# <p>In
# Updating Regression Analysis using Linear Algebra and NumPy - Code Along at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131757
# Sucess!! Done with Regression Analysis using Linear Algebra and NumPy - Code Along, moving on to the next one.
# Fixing Computational Complexity: From OLS to Gradient Descent
# <h1>Computational Complexity: From OLS to Gradient Descent</h1>
# <h2>Introduction</h2>
# <p>In this les
# Updating Computational Complexity: From OLS to Gradient Descent at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/computational-complexity-from-ols-to-gradient-descent
# Sucess!! Done with Computational Complexity: From OLS to Gradient Descent, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Introduction to Derivatives
# <h1>Introduction to Derivatives</h1>
# <h2>Introduction</h2>
# <p>In the linear regression section, you
# Updating Introduction to Derivatives at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131726
# Sucess!! Done with Introduction to Derivatives, moving on to the next one.
# Fixing Derivatives of Non-Linear Functions
# <h1>Derivatives of Non-Linear Functions</h1>
# <h2>Introduction</h2>
# <p>In the last lesson, we saw tha
# Updating Derivatives of Non-Linear Functions at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131696
# Sucess!! Done with Derivatives of Non-Linear Functions, moving on to the next one.
# Fixing Rules for Derivatives
# <h1>Rules for Derivatives</h1>
# <h2>Introduction</h2>
# <p>In the previous lesson, we calculated the de
# Updating Rules for Derivatives at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131766
# Sucess!! Done with Rules for Derivatives, moving on to the next one.
# Fixing Derivatives: Conclusion
# <h1>Derivatives: Conclusion</h1>  <h2>Introduction</h2>  <p>Data science is all about finding good m
# Updating Derivatives: Conclusion at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131695
# Sucess!! Done with Derivatives: Conclusion, moving on to the next one.
# Fixing Introduction to Gradient Descent
# <h1>Introduction to Gradient Descent</h1>
# <h2>Introduction</h2>
# <p>It's possible to solve for the op
# Updating Introduction to Gradient Descent at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131728
# Sucess!! Done with Introduction to Gradient Descent, moving on to the next one.
# Fixing Gradient Descent: Step Sizes
# <h1>Gradient Descent: Step Sizes</h1>
# <h2>Introduction</h2>
# <p>In the last section, you took a first
# Updating Gradient Descent: Step Sizes at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131713
# Sucess!! Done with Gradient Descent: Step Sizes, moving on to the next one.
# Fixing Gradient Descent in 3D
# <h1>Gradient Descent in 3D</h1>  <h2>Introduction</h2>  <p>Previously, we talked about how to think
# Updating Gradient Descent in 3D at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131711
# Sucess!! Done with Gradient Descent in 3D, moving on to the next one.
# Fixing  The Gradient in Gradient Descent
# <h1>The Gradient in Gradient Descent</h1>
# <h2>Introduction</h2>
# <p>As you know, we entered our discu
# Updating  The Gradient in Gradient Descent at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/the-gradient-in-gradient-descent
# Sucess!! Done with  The Gradient in Gradient Descent, moving on to the next one.
# Fixing Gradient to Cost Function
# <h1>Gradient to Cost Function</h1>
# <h2>Introduction</h2>
# <p>In the previous lesson, we learned the m
# Updating Gradient to Cost Function at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131715
# Sucess!! Done with Gradient to Cost Function, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Regularization - Introduction
# <h1>Regularization - Introduction</h1>  <h2>Introduction</h2>  <p>In an attempt to fit a good model
# Updating Regularization - Introduction at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/regularization-introduction
# Sucess!! Done with Regularization - Introduction, moving on to the next one.
# Fixing Ridge and Lasso Regression
# <h1>Ridge and Lasso Regression</h1>  <h2>Introduction</h2>  <p>At this point, you've seen a number o
# Updating Ridge and Lasso Regression at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131762
# Sucess!! Done with Ridge and Lasso Regression, moving on to the next one.
# Fixing Feature and Model Selection: AIC and BIC
# <h1>Feature and Model Selection: AIC and BIC</h1>  <h2>Introduction</h2>  <p>Previously, you've seen
# Updating Feature and Model Selection: AIC and BIC at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/feature-and-model-selection-aic-and-bic
# Sucess!! Done with Feature and Model Selection: AIC and BIC, moving on to the next one.
# Fixing Feature Selection Methods
# <h1>Feature Selection Methods</h1>
# <h2>Introduction</h2>
# <p>In a previous section, you learned about
# Updating Feature Selection Methods at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131704
# Sucess!! Done with Feature Selection Methods, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Linear to Logistic Regression
# <h1>Linear to Logistic regression</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll be introduc
# Updating Linear to Logistic Regression at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131733
# Sucess!! Done with Linear to Logistic Regression, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Evaluation Metrics
# <h1>Evaluation Metrics</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn about common <st
# Updating Evaluation Metrics at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/evaluation-metrics
# Sucess!! Done with Evaluation Metrics, moving on to the next one.
# Fixing ROC Curves and AUC
# <h1>ROC Curves and AUC</h1>  <h2>Introduction</h2>  <p>This lesson will introduce ROC: Receiver Oper
# Updating ROC Curves and AUC at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131764
# Sucess!! Done with ROC Curves and AUC, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing MLE Review
# <h1>MLE Review</h1>
# <h2>Introduction</h2>
# <p>You've seen MLE (Maximum Likelihood Estimation) when di
# Updating MLE Review at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/mle-review
# Sucess!! Done with MLE Review, moving on to the next one.
# Fixing MLE and Logistic Regression-2
# ...
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing PCA Background: Covariance Matrix and Eigendecomposition
# <h1>PCA Background: Covariance Matrix and Eigendecomposition</h1>  <h2>Introduction</h2>  <p>Now tha
# Updating PCA Background: Covariance Matrix and Eigendecomposition at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131825
# Sucess!! Done with PCA Background: Covariance Matrix and Eigendecomposition, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Clustering - Introduction
# <h1>Clustering - Introduction</h1>  <h2>Introduction</h2>  <p>In this section, you'll learn about a
# Updating Clustering - Introduction at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/clustering-introduction
# Sucess!! Done with Clustering - Introduction, moving on to the next one.
# Fixing K-means Clustering
# <h1>K-means Clustering</h1>  <h2>Introduction</h2>  <p>In this lesson, we'll learn about the most po
# Updating K-means Clustering at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/k-means-clustering
# Sucess!! Done with K-means Clustering, moving on to the next one.
# Fixing Hierarchical Agglomerative Clustering
# <h1>Hierarchical Agglomerative Clustering</h1>  <h2>Introduction</h2>  <p>In this lesson, we'll lear
# Updating Hierarchical Agglomerative Clustering at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/hierarchical-agglomerative-clustering
# Sucess!! Done with Hierarchical Agglomerative Clustering, moving on to the next one.
# Fixing Common Problems with Clustering Algorithms
# <h1>Common Problems with Clustering Algorithms</h1>  <h2>Introduction</h2>  <p>In this lesson, we'll
# Updating Common Problems with Clustering Algorithms at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/common-problems-with-clustering-algorithms
# Sucess!! Done with Common Problems with Clustering Algorithms, moving on to the next one.
# Fixing Hierarchical Agglomerative Clustering - Codealong
# <h1>Hierarchical Agglomerative Clustering - Codealong</h1>  <h2>Introduction</h2>  <p>In this codeal
# Updating Hierarchical Agglomerative Clustering - Codealong at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131798
# Sucess!! Done with Hierarchical Agglomerative Clustering - Codealong, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Clustering - Recap
# <h1>Clustering - Recap</h1>
# <h2>Key Takeaways</h2>
# <p>The key takeaways from this section include:</
# Updating Clustering - Recap at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/clustering-recap
# Sucess!! Done with Clustering - Recap, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Introduction to Recommendation Systems
# <h1>Introduction to Recommendation Systems</h1>  <h2>Introduction</h2>  <p>This lesson will give you
# Updating Introduction to Recommendation Systems at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/introduction-to-recommendation-systems
# Sucess!! Done with Introduction to Recommendation Systems, moving on to the next one.
# Fixing Collaborative Filtering and Singular Value Decomposition
# <h1>Collaborative Filtering with Singular Value Decomposition</h1>
# <h2>Introduction</h2>
# <p>Recommen
# Updating Collaborative Filtering and Singular Value Decomposition at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131785
# Sucess!! Done with Collaborative Filtering and Singular Value Decomposition, moving on to the next one.
# Fixing Collaborative Filtering with Surprise
# <h1>Implementing Recommendation Engines with <code>surprise</code></h1>  <h2>Introduction</h2>  <p>T
# Updating Collaborative Filtering with Surprise at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131786
# Sucess!! Done with Collaborative Filtering with Surprise, moving on to the next one.
# Fixing Matrix Factorization with Alternating Least Squares
# <h1>Matrix Factorization with Alternating Least Squares</h1>
# <h2>Introduction</h2>
# <p>In this lesson
# Updating Matrix Factorization with Alternating Least Squares at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131816
# Sucess!! Done with Matrix Factorization with Alternating Least Squares, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Types of Trends
# <h1>Types of Trends</h1>  <h2>Introduction</h2>  <p>Often, basic regression techniques are not suffi
# Updating Types of Trends at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131850
# Sucess!! Done with Types of Trends, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Basic Time Series Models
# <h1>Basic Time Series Models</h1>  <h2>Introduction</h2>  <p>We've looked at time series and what th
# Updating Basic Time Series Models at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131780
# Sucess!! Done with Basic Time Series Models, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing ARMA Models
# <h1>ARMA Models</h1>
# <h2>Introduction</h2>
# <p>You've seen two basic time series models now, the rand
# Updating ARMA Models at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/arma-models
# Sucess!! Done with ARMA Models, moving on to the next one.
# Fixing ARMA Models in statsmodels
# <h1>ARMA Models in <code>statsmodels</code></h1>  <h2>Introduction</h2>  <p>In this lesson, you'll u
# Updating ARMA Models in statsmodels at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131778
# Sucess!! Done with ARMA Models in statsmodels, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing NLP and Word Vectorization
# <h1>NLP and Word Vectorization</h1>  <h2>Introduction</h2>  <p>In this lesson, we'll learn about som
# Updating NLP and Word Vectorization at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/nlp-and-word-vectorization
# Sucess!! Done with NLP and Word Vectorization, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Introduction to Neural Networks
# <h1>Introduction to Neural Networks</h1>
# <h2>Introduction</h2>
# <p>Neural networks are becoming incre
# Updating Introduction to Neural Networks  at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131806
# Sucess!! Done with Introduction to Neural Networks , moving on to the next one.
# Fixing Introduction to Keras
# <h1>Introduction to Keras</h1>  <h2>Introduction</h2>  <p>Thus far we have a solid basic conceptual
# Updating Introduction to Keras at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131803
# Sucess!! Done with Introduction to Keras, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Deeper Neural Networks
# <h1>Deeper Neural Networks</h1>
# <h2>Introduction</h2>
# <p>Some of the most powerful neural networks u
# Updating Deeper Neural Networks at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131794
# Sucess!! Done with Deeper Neural Networks, moving on to the next one.
# Fixing Image Classification with Multi-Layer Perceptrons
# <h1>Image Classification with Multi-Layer Perceptrons</h1>
# <h2>Introduction</h2>
# <p>In this lesson,
# Updating Image Classification with Multi-Layer Perceptrons at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/image-classification-with-multi-layer-perceptrons
# Sucess!! Done with Image Classification with Multi-Layer Perceptrons, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Tuning Neural Networks with Regularization
# <h1>Tuning Neural Networks with Regularization</h1>  <h2>Introduction</h2>  <p>Now that you've learn
# Updating Tuning Neural Networks with Regularization at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/tuning-neural-networks-with-regularization
# Sucess!! Done with Tuning Neural Networks with Regularization, moving on to the next one.
# Fixing Tuning Neural Networks with Normalization
# <h1>Tuning Neural Networks with Normalization</h1>
# <h2>Introduction</h2>
# <p>Now that we've investiga
# Updating Tuning Neural Networks with Normalization at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/tuning-neural-networks-with-normalization
# Sucess!! Done with Tuning Neural Networks with Normalization, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Simple and Shortest Paths
# <h1>Graph Theory: Simple and Shortest Paths</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll i
# Updating Simple and Shortest Paths at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131840
# Sucess!! Done with Simple and Shortest Paths, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Network Clustering
# <h1>Network Clustering</h1>  <h2>Introduction</h2>  <p>You've now looked at some basic measures of n
# Updating Network Clustering at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131817
# Sucess!! Done with Network Clustering, moving on to the next one.
# Fixing Recommendation Systems
# <h1>Recommendation Systems</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll investigate a very
# Updating Recommendation Systems at
#  https://learning.flatironschool.com/api/v1/courses/4713/assignments/131835
# Sucess!! Done with Recommendation Systems, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Convolutional Neural Networks
# <h1>Convolutional Neural Networks</h1>
# <h2>Introduction</h2>
# <p>Convolutional Neural Networks (CNNs)
# Updating Convolutional Neural Networks at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/convolutional-neural-networks
# Sucess!! Done with Convolutional Neural Networks, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item
# Fixing Sequence Model Use Cases
# <h1>Sequence Model Use Cases</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn about <str
# Updating Sequence Model Use Cases at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/sequence-model-use-cases
# Sucess!! Done with Sequence Model Use Cases, moving on to the next one.
# Fixing Understanding Recurrent Neural Networks
# <h1>Understanding Recurrent Neural Networks</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll l
# Updating Understanding Recurrent Neural Networks at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/understanding-recurrent-neural-networks
# Sucess!! Done with Understanding Recurrent Neural Networks, moving on to the next one.
# Fixing LSTMs and GRUs
# <h1>LSTMs and GRUs</h1>  <h2>Introduction</h2>  <p>In this lesson, you'll learn about two advanced t
# Updating LSTMs and GRUs at
#  https://learning.flatironschool.com/api/v1/courses/4713/pages/lstms-and-grus
# Sucess!! Done with LSTMs and GRUs, moving on to the next one.
# Not a LaTeX Repo
# None does not have any LaTeX formulas in it
# Moving on to the next item

# %%
lessons = lessons_list('full_course_download.yml')
lessons[28929]
# Out:
# ['https://learning.flatironschool.com/api/v1/courses/4713/assignments/131387',
#  'https://learning.flatironschool.com/api/v1/courses/4713/assignments/131384',
#  'https://learning.flatironschool.com/api/v1/courses/4713/assignments/131383',
#  'https://learning.flatironschool.com/api/v1/courses/4713/assignments/131360',
#  'https://learning.flatironschool.com/api/v1/courses/4713/assignments/131406',
#  'https://learning.flatironschool.com/api/v1/courses/4713/assignments/131404',
#  'https://learning.flatironschool.com/api/v1/courses/4713/assignments/131358']

# %%
for mod in mod_list:
    try:
        fix_mod(mod)
        mod_list.remove(mod)
        print(f'mod {mod} done')
    except:
        print(f'mod {mod} completed')
